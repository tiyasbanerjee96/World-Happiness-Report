# %% [markdown]
# # World Happiness Report Exploratory Data Analysis

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Reading the data

# %%
data=pd.read_csv('C:\\Users\\TIYAS\\Downloads\\archive (8)\\world-happiness-report.csv')

# %% [markdown]
# ### To view all the data

# %%
data
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# ### To check how many rows and columns are there

# %%
data.shape
# Out:
# (1949, 11)

# %% [markdown]
# ### To print fields name

# %%
data.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %% [markdown]
# ### To check the data types of attributes

# %%
data.dtypes
# Out:
# Country name                         object
# year                                  int64
# Life Ladder                         float64
# Log GDP per capita                  float64
# Social support                      float64
# Healthy life expectancy at birth    float64
# Freedom to make life choices        float64
# Generosity                          float64
# Perceptions of corruption           float64
# Positive affect                     float64
# Negative affect                     float64
# dtype: object

# %% [markdown]
# ### To check if there are some mising values

# %%
data.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Positive affect                      22
# Negative affect                      16
# dtype: int64

# %% [markdown]
# ### To print 5 records

# %%
data.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %% [markdown]
# ### To print bottom 5 records

# %%
data.tail()
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1944                              54.4                         0.733
# 1945                              55.0                         0.753
# 1946                              55.6                         0.763
# 1947                              56.2                         0.632
# 1948                              56.8                         0.643
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# ...

# %% [markdown]
# ### Print information of Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %% [markdown]
# ### To print statistical information

# %%
data.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %%
data.describe(include='all')
# Out:
#        Country name         year  Life Ladder  Log GDP per capita  \
# count          1949  1949.000000  1949.000000         1913.000000
# unique          166          NaN          NaN                 NaN
# top           Ghana          NaN          NaN                 NaN
# freq             15          NaN          NaN                 NaN
# mean            NaN  2013.216008     5.466705            9.368453
# std             NaN     4.166828     1.115711            1.154084
# min             NaN  2005.000000     2.375000            6.635000
# 25%             NaN  2010.000000     4.640000            8.464000
# 50%             NaN  2013.000000     5.386000            9.460000
# 75%             NaN  2017.000000     6.283000           10.353000
# max             NaN  2020.000000     8.019000           11.648000
#
#         Social support  Healthy life expectancy at birth  \
# count      1936.000000                       1894.000000
# ...

# %% [markdown]
# ### To check if there is any duplicated value

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Drop a column

# %%
data=data.drop(['Perceptions of corruption'],axis=1)

# %% [markdown]
# ### To count number of categories

# %%
data['Healthy life expectancy at birth'].value_counts()
# Out:
# 72.20    15
# 67.20    14
# 66.40    14
# 73.00    14
# 66.60    13
#          ..
# 73.68     1
# 47.18     1
# 63.82     1
# 61.88     1
# 62.24     1
# Name: Healthy life expectancy at birth, Length: 828, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Plot a graph Positive affect Vs quantity

# %%
plt.bar(data['year'],data['Life Ladder'])
plt.title('year Vs Life Ladder',fontsize=15,color='red')
plt.xlabel('year',fontsize=15)
plt.ylabel('Life Ladder',fontsize=15)
plt.grid(True)
plt.show()

# %%
data.sort_values(by=['Generosity'])
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 647        Greece  2018        5.409              10.299           0.794
# 640        Greece  2011        5.372              10.339           0.852
# 1440       Russia  2006        4.964               9.991           0.895
# 1442       Russia  2008        5.619              10.125           0.882
# 641        Greece  2012        5.096              10.268           0.812
# ...           ...   ...          ...                 ...             ...
# 1892    Venezuela  2019        5.081                 NaN           0.888
# 1893    Venezuela  2020        4.574                 NaN           0.805
# 1905      Vietnam  2017        5.175               8.876             NaN
# 1918        Yemen  2018        3.058                 NaN           0.789
# 1919        Yemen  2019        4.197                 NaN           0.870
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# ### Maximum of Life Ladder

# %%
data['Life Ladder'].max()
# Out:
# 8.019

# %% [markdown]
# ### Minimum of Life Ladder

# %%
data['Life Ladder'].min()
# Out:
# 2.375

# %%
data1=data.copy()
data1=data1.pivot_table('year',columns='Healthy life expectancy at birth',aggfunc='sum')
data1
# Out:
# Healthy life expectancy at birth  32.300  36.860  40.300  40.380  40.808  \
# year                                2010    2011    2006    2008    2011
#
# Healthy life expectancy at birth  40.900  41.200  41.420  41.580  42.100  ...  \
# year                                2007    2007    2012    2006    2008  ...
#
# Healthy life expectancy at birth  75.020  75.100  75.200  75.460  75.680  \
# year                                2011    2019    2020    2013    2014
#
# Healthy life expectancy at birth  75.900  76.200  76.500  76.800  77.100
# year                                2015    2016    2017    2018    2019
#
# [1 rows x 828 columns]

# %%
data2=data.copy()
data2=data2.pivot_table('Country name',columns='Log GDP per capita',aggfunc='sum')
data2
# Out:
# Log GDP per capita   6.635   6.678    6.719    6.723             6.728   \
# Country name        Burundi  Malawi  Burundi  Burundi  Congo (Kinshasa)
#
# Log GDP per capita  6.742    6.748       6.776                     6.785   \
# Country name        Malawi  Burundi  Mozambique  Central African Republic
#
# Log GDP per capita   6.787   ...      11.567      11.580      11.592  \
# Country name        Burundi  ...  Luxembourg  Luxembourg  Luxembourg
#
# Log GDP per capita      11.595      11.598      11.617      11.634  \
# Country name        Luxembourg  Luxembourg  Luxembourg  Luxembourg
#
# Log GDP per capita      11.640      11.645      11.648
# Country name        Luxembourg  Luxembourg  Luxembourg
#
# [1 rows x 1500 columns]

# %%
data3=data.copy()
data3=data3.pivot_table('Country name',columns='Freedom to make life choices',aggfunc='sum')
data3
# Out:
# Freedom to make life choices                   0.258    0.260 0.281 0.287  \
# Country name                  Bosnia and Herzegovina  Burundi  Cuba  Togo
#
# Freedom to make life choices 0.295  0.304 0.306 0.315       0.332  \
# Country name                  Chad  Haiti  Chad  Iraq  Madagascar
#
# Freedom to make life choices                   0.333  ...            0.963  \
# Country name                  Bosnia and Herzegovina  ...  CambodiaDenmark
#
# Freedom to make life choices           0.964   0.965    0.968    0.969  \
# Country name                  CambodiaSweden  Norway  Somalia  Finland
#
# Freedom to make life choices                        0.970    0.971  \
# Country name                  DenmarkUzbekistanUzbekistan  Denmark
#
# Freedom to make life choices       0.980       0.984       0.985
# Country name                  Uzbekistan  Uzbekistan  Uzbekistan
#
# [1 rows x 535 columns]

# %%
plt.bar(data['year'],data['Healthy life expectancy at birth'])
plt.title('year Vs Healthy life expectancy at birth',fontsize=15,color='blue')
plt.xlabel('year',fontsize=15)
plt.ylabel('Healthy life expectancy at birth',fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.relplot(x='year',y='Generosity',color='green',data=data)
plt.show()

# %%
sns.countplot(x='year',data=data,palette='coolwarm')
plt.show()

# %%
plt.title('year',fontsize=20)
data['year'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
sns.countplot(x='year',data=data,palette='tab10')
plt.show()

# %%
data.groupby('year')[['Life Ladder','Social support']].sum().plot.bar(color=['red','green'],figsize=(8,5))
plt.ylabel('Life Ladder and Social support')
plt.show()

# %%
data.hist(figsize=(13,13),layout=(3,3),sharex=False)
plt.show()

# %%
data.plot(kind='box',figsize=(13,13),layout=(4,4),subplots=True,sharex=False)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.pairplot(data,hue='year')
plt.show()
